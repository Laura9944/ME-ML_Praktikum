# %% [markdown]
# # 2a: Statistik

# %% [markdown]
# ## 1. Dichte, Erwartungswert, Varianz und Kovarianz
#
#     Eine 1D-Zufallsvariable x sei im Intervall [a,b] c R gleichverteilt

# %% [markdown]
# a) Skizzieren Sie die Dichte p(x).
#
# Welchen Wert hat die Dichte im Intervall [a, b]?

# %% [markdown]
# b) Berechnen Sie den Erwartungswert

# %% [markdown]
# c) Berechnen Sie die Varianz

# %% [markdown]
# ## 2.Sample Mean und Kovarianzmatrix
#
# Gegeben ist eine Stichprobe X einer vektoriellen Zufallsvariable x = (x_1, x_2) e R2, i = 1, .., 4:
#
#     X = {x_1=(1, 2), x_2=(-1, -1), x_3=(-5, 1), x_4=(1, 2)}

# %% [markdown]
# a) Berechnen Sie den Mittelwertsvektor

# %% [markdown]
# b) Berechnen Sie die Autokovarianzmatrix

# %% [markdown]
# ## 3. Multivariate Normalverteilung
#
# Eine Zufallsvariable u = (x , y) sei normalverteilt mit Mittelwertsvektor $\mu_u = (0,0)^T$ und Kovarianzmatrix ...

# %% [markdown]
# a) Skizzieren Sie die Lage und die Ausrichtung der beiden Vektoren im x/y- Koordinatensystem durch Ellipsen

# %% [markdown]
# b) Wie etwa würde die Trennfunktion eines Klassifikators aussehen? (Die A-priori-Wahrscheinlichkeit der beiden Verteilungen einen gleich, Skizze)

# %% [markdown]
# ## 4. Entropie einer Diskreten Verteilung
#
# Es ist folgende diskrete Wahrscheinlichkeitsverteilung gegeben ...
#
# Verwenden Sie bei den Berechnungen den natürlichen Logarithmus ln(x)

# %% [markdown]
# a) Welchen Wert hat die Information x = 1?

# %% [markdown]
# b) Welchen Wert hat die Information x = 2?

# %% [markdown]
# c) Welche Entropie hat diese Verteilung?

# %% [markdown]
# d) Wenn $P_1 = 0.1$ wäre, wäre die Entropie dann größer oder kleiner?
#
# Warum ist das so?

# %% [markdown]
# # 2b: Statistik

# %% [markdown]
# Berechnung von Mittelwertsvektor $\mu$ und Kovarianzmatrix $\sum$ für obige Stichprobe

# %% [markdown]
# Plotten von Normalverteilungen für d = 2 Dimensionen für verschiedene $\mu$, $\sum$ als
#
# * 3D-Oberfläche
# * Höhenlinienbld (Konturbild)
# * 2D-Verteilung von zufälligen Samples
